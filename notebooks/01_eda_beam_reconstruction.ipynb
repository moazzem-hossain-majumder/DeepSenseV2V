# %% [markdown]
# # Beam Reconstruction and Feasibility Check
#
# Verifies the 256-beam power-vector reconstruction and runs the near-optimal set size feasibility check.

# %%
import os
os.chdir(r'D:\424_project-main')  # ensure relative paths resolve from project root

# %%
from src.beam_reconstruction import verify_reconstruction_and_feasibility
stats = verify_reconstruction_and_feasibility(output_dir='results/eda')
print('Match rate:', stats['match_rate'])
print('Mean beams within 1 dB:', stats['mean_beams_1db'])
print('Mean beams within 3 dB:', stats['mean_beams_3db'])
# Out:
# Loading D:\DeepSense_V2V\data\scenario36.p...
# Total samples in pickle: 24,799
# [Feasibility Gate 1] 256-Beam Argmax Match Rate: 100.00% (24,799 / 24,799)
#
# [Feasibility Gate 2] Near-Optimal Beam Set Sizes:
#   Within 1 dB: Mean = 11.75, Median = 3.0, Max = 192
#   Within 3 dB: Mean = 29.69, Median = 5.0, Max = 256
#
# [Feasibility Gate 3] Best-Beam Class Distribution:
#   Active beam classes: 238 / 256
#   Majority beam class: Beam #162 (16.71% of samples)
# Saved feasibility figure to results/eda\near_optimal_set_sizes.png
# Match rate: 1.0
# Mean beams within 1 dB: 11.747651114964313
# Mean beams within 3 dB: 29.686600266139763
