# %% [markdown]
# # Phase 3 — GPS branch
#
# Local ENU, distance/bearing, velocity proxies, HDOP flag. Scaler fit on train only.

# %%
from src.gps_features import GPS_FEATURE_NAMES, extract_sequence_gps_features
print(GPS_FEATURE_NAMES)
