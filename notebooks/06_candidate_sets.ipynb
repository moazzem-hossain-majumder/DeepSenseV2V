# %% [markdown]
# # Candidate Set Analysis
#
# Demonstrates Top-k candidate sets and conformal risk control using actual model predictions.

# %%
import os
os.chdir(r'D:\424_project-main')  # ensure relative paths resolve from project root

# %%
import pandas as pd
import numpy as np
import os
from src.candidate_sets import build_topk_candidate_set, evaluate_fixed_topk

topk_path = 'results/topk_candidate_sets.csv'
if os.path.exists(topk_path):
    print('Top-k candidate set results:')
    print(pd.read_csv(topk_path).to_string(index=False))
else:
    print('Results not found — run python -m src.complete_blueprint_steps first.')

tel_path = 'results/telecom_utility_table.csv'
if os.path.exists(tel_path):
    print('\nConformal controller results:')
    print(pd.read_csv(tel_path).to_string(index=False))
# Out:
# Top-k candidate set results:
# method  k_or_q  exact_inclusion  miss_rate_delta_3.0db  avg_size  avg_power_loss_db  search_reduction_vs_256
#   top1       1         0.126566               0.595551       1.0          10.129041                 0.996094
#   top3       3         0.323935               0.230107       3.0           3.744910                 0.988281
#   top5       5         0.467888               0.163534       5.0           1.873112                 0.980469
#  top10      10         0.606830               0.093515      10.0           1.206720                 0.960938
#  top15      15         0.663534               0.062500      15.0           0.962890                 0.941406
#
# Conformal controller results:
#           method  miss_rate  avg_probes  search_reduction   apl_db  outage_p_gap_gt_3db  eta_from_val_only  q_max_calib_p99  exact_coverage
# ...
